# %%
import pandas as pd

movies = pd.read_csv('data/ratings_movies.csv', sep=',')
movies
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
movies['year_release']=movies['title'].apply(get_year_release)
movies
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
mask = movies['year_release'] == 2010
movies[mask].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
def sor(*arg):
    lis=[]
    for i in arg:
        if i not in lis:
            lis.append(arg)
        else:
            None    
    return len(lis)    
movies.groupby('userId')['genres'].nunique().sort_values()
# Out:
# userId
# 214     13
# 85      13
# 245     13
# 494     15
# 578     15
#       ...
# 474    395
# 380    399
# 448    403
# 414    482
# 599    524
# Name: genres, Length: 610, dtype: int64

# %%
movies.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mm1=movies['year_release']==2018
movies[mm1].groupby('genres')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[False, True])
# Out:
#                                         count      mean
# genres
# Action|Adventure|Sci-Fi                    14  3.928571
# Action|Comedy|Sci-Fi                       12  3.875000
# Comedy                                      8  3.312500
# Animation|Comedy                            5  3.500000
# Action|Adventure|Children|Sci-Fi            5  3.900000
# Action|Adventure|Fantasy                    4  2.500000
# Drama|Horror|Thriller                       4  2.750000
# Action|Adventure|Animation|Children         4  3.000000
# Action|Adventure|Comedy|Fantasy|Sci-Fi      3  3.666667
# Adventure|Mystery|Sci-Fi|Thriller           3  3.833333
# Horror|Mystery|Sci-Fi|Thriller              2  2.250000
# Action|Fantasy|Sci-Fi                       2  2.750000
# Action|Adventure|Drama|Sci-Fi|Thriller      2  3.250000
# Comedy|Drama                                2  3.250000
# Action|Adventure|Thriller                   2  3.750000
# Documentary                                 2  4.000000
# ...

# %%
movies['date']= pd.to_datetime(movies['date'], dayfirst=True)

movies['year_rating']=movies['date'].dt.year
ap=movies.pivot_table(
    values='rating',
    index='genres',
    columns='year_rating',
    aggfunc='mean'
)
ap.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 951 entries, (no genres listed) to Western
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1996    195 non-null    float64
#  1   1997    199 non-null    float64
#  2   1998    146 non-null    float64
#  3   1999    291 non-null    float64
#  4   2000    407 non-null    float64
#  5   2001    368 non-null    float64
#  6   2002    393 non-null    float64
#  7   2003    390 non-null    float64
#  8   2004    390 non-null    float64
#  9   2005    461 non-null    float64
#  10  2006    394 non-null    float64
#  11  2007    516 non-null    float64
#  12  2008    438 non-null    float64
#  13  2009    468 non-null    float64
#  14  2010    418 non-null    float64
#  15  2011    341 non-null    float64
#  16  2012    478 non-null    float64
#  17  2013    328 non-null    float64
#  18  2014    313 non-null    float64
#  19  2015    548 non-null    float64
# ...

# %%
t1= pd.read_csv('data/orders.csv', sep=';')
t2= pd.read_csv('data/products.csv', sep=';')
display(t1)
display(t2)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products = t1.merge(
    t2, 
    left_on='ID товара',
    right_on='Product_ID',
    how='left')
orders_products
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
mmm=orders_products['Оплачен']=='да'
op=orders_products
op['ssmm']=op['Количество']*op['Price']
op
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...
